# %% [markdown]
# # KAGGLE LOL - player_1 - Tim Claytor

# %% [markdown]
# ## Library Imports

# %%
#numpy
import numpy as np
#pandas
import pandas as pd
#matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Datasets

# %% [markdown]
# ### Champion Mastery Data

# %% [markdown]
# #### Read & Head

# %%
champion_mastery = pd.read_csv('../data/champion_mastery.csv')
champion_mastery.head()
# Out:
#    summonerId  championId  championLevel  championPoints  chestGranted  \
# 0       18687         161              7          517126          True
# 1       18687         121              6           67420          True
# 2       18687          56              5           61069          True
# 3       18687          32              5           44528         False
# 4       18687          53              5           44024         False
#
#    tokensEarned
# 0             0
# 1             0
# 2             2
# 3             2
# 4             2

# %% [markdown]
# #### Info

# %%
champion_mastery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5814028 entries, 0 to 5814027
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   summonerId      int64
#  1   championId      int64
#  2   championLevel   int64
#  3   championPoints  int64
#  4   chestGranted    bool
#  5   tokensEarned    int64
# dtypes: bool(1), int64(5)
# memory usage: 227.3 MB

# %% [markdown]
# #### Summoner level Information

# %%
champion_mastery['summonerLevel'].describe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'summonerLevel'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.hist(champion_mastery['summonerLevel'], bins=100)
plt.title("Distribution of Summoner Levels")
plt.xlabel('Level')
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Champion Data

# %% [markdown]
# #### Read and Head

# %%
champion = pd.json_normalize(pd.read_json('../data/champion.json')['data'])

# %% [markdown]
# #### Info

# %%
champion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   version                     162 non-null    object
#  1   id                          162 non-null    object
#  2   key                         162 non-null    object
#  3   name                        162 non-null    object
#  4   title                       162 non-null    object
#  5   blurb                       162 non-null    object
#  6   tags                        162 non-null    object
#  7   partype                     162 non-null    object
#  8   info.attack                 162 non-null    int64
#  9   info.defense                162 non-null    int64
#  10  info.magic                  162 non-null    int64
#  11  info.difficulty             162 non-null    int64
#  12  image.full                  162 non-null    object
# ...

# %%
#Looking at the Stats Table
champion.iloc[:,19:].describe()
# Out:
#          stats.hp  stats.hpperlevel      stats.mp  stats.mpperlevel  \
# count  162.000000        162.000000    162.000000        162.000000
# mean   620.265432        103.635802    374.030864         37.358025
# std     40.741999          8.607202    770.192195         19.975254
# min    410.000000         69.000000      0.000000          0.000000
# 25%    598.500000         99.000000    280.000000         28.000000
# 50%    630.000000        104.000000    326.500000         40.000000
# 75%    650.000000        109.000000    383.000000         50.000000
# max    696.000000        129.000000  10000.000000         87.000000
#
#        stats.movespeed  stats.armor  stats.armorperlevel  stats.spellblock  \
# count       162.000000   162.000000           162.000000        162.000000
# mean        336.222222    29.796296             4.639815         30.796296
# std           7.085108     6.494277             0.524023          1.709087
# ...

# %% [markdown]
# ### Item Data

# %%
import json

with open('../data/item.json', 'r') as f:
    data = json.load(f)

item = pd.json_normalize(data)


#item = pd.json_normalize(
#    data,
#    record_path[]
item
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/chunderdamus/Documents/NSS/NSS_Projects/kaggle_lol-player_one/notebooks/claytor.ipynb Cell 20 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/home/chunderdamus/Documents/NSS/NSS_Projects/kaggle_lol-player_one/notebooks/claytor.ipynb#Y104sZmlsZQ%3D%3D?line=2'>3</a> with open('../data/item.json', 'r') as f:
#       <a href='vscode-notebook-cell:/home/chunderdamus/Documents/NSS/NSS_Projects/kaggle_lol-player_one/notebooks/claytor.ipynb#Y104sZmlsZQ%3D%3D?line=3'>4</a>     data = json.load(f)
# ----> <a href='vscode-notebook-cell:/home/chunderdamus/Documents/NSS/NSS_Projects/kaggle_lol-player_one/notebooks/claytor.ipynb#Y104sZmlsZQ%3D%3D?line=5'>6</a> item = pd.json_normalize(data, 'basic')
# ...

# %% [markdown]
# ### Participants Test Data

# %%
#read data
participants_test = pd.read_csv('../data/participants_test.csv')
participants_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   matchId        20000 non-null  int64
#  1   teamId         20000 non-null  int64
#  2   participantId  20000 non-null  int64
#  3   summonerId     20000 non-null  int64
#  4   summonerLevel  20000 non-null  int64
#  5   championName   20000 non-null  object
#  6   championId     20000 non-null  int64
# dtypes: int64(6), object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Participants Train Data

# %%
#read data
participants_train = pd.read_csv('../data/participants_train.csv')
participants_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   matchId        80000 non-null  int64
#  1   teamId         80000 non-null  int64
#  2   participantId  80000 non-null  int64
#  3   summonerId     80000 non-null  int64
#  4   summonerLevel  80000 non-null  int64
#  5   championName   80000 non-null  object
#  6   championId     80000 non-null  int64
# dtypes: int64(6), object(1)
# memory usage: 4.3+ MB

# %% [markdown]
# ### Winners Train Data

# %%
#read data
winners_train = pd.read_csv('../data/train_winners.csv')
winners_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   matchId  8000 non-null   int64
#  1   winner   8000 non-null   int64
# dtypes: int64(2)
# memory usage: 125.1 KB

# %% [markdown]
# ## Models
